# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
from plotting import plot
from yaml import load
from yaml import CLoader as Loader
ds = xr.open_dataset("/home/phyto/ModelOutput/merged/biomass_menden.nc")
ds2 = xr.open_dataset("/home/phyto/CoccoML/data/envdata_final.nc")
ds['FID'] = ds2['FID']
ds2 = None



p = plot(ds)
ds = None

# %%
traits = pd.read_csv("/home/phyto/CoccoML/data/traits.csv")

fig, axs = plt.subplots(2,1,figsize=(20, 8))
fig.suptitle('Top contributors per oceanographic region')
p.top_size_groups_boxplot(traits, region="Northern Temperate Gyres", log=True, ax=axs[0])
p.top_size_groups_boxplot(traits, region="Southern Subantarctic", log=True, ax=axs[1])
fig.tight_layout()
# Out:
# dict_items([('3-4 um', {'species': ['Gephyrocapsa ericsonii', 'Florisphaera profunda', 'Syracosphaera prolongata type', 'Gephyrocapsa muellerae']}), ('5 um', {'species': ['Emiliania huxleyi', 'Discosphaera tubifera', 'Algirosphaera robusta', 'Gephyrocapsa oceanica', 'Ophiaster hydroideus', 'Calciosolenia murrayi', 'Oolithotus antillarum']}), ('6-7 um', {'species': ['Umbellosphaera irregularis', 'Umbellosphaera tenuis', 'Rhabdosphaera clavigera', 'Acanthoica quattrospina', 'Syracosphaera molischii type', 'Umbilicosphaera sibogae', 'Helicosphaera carteri', 'Michaelsarsia elegans', 'Syracosphaera nodosa type', 'Umbilicosphaera hulburtiana', 'Gladiolithus flabellatus', 'Rhabdosphaera xiphos', 'Syracosphaera aurisinae HOL type', 'Syracosphaera dilatata type']}), ('8-12 um', {'species': ['Syracosphaera pulchra', 'Calcidiscus leptoporus', 'Calciosolenia brasiliensis', 'Syracosphaera pulchra HOL', 'Syracosphaera anthos type', 'Michaelsarsia adriaticus', 'Palusphaera vandelii', 'Syracosphaera halldalii type', 'Alisphaera unicornis type']}), ('13-16 um', {'species': ['Coronosphaera mediterranea', 'Oolithotus fragilis', 'Coccolithus pelagicus', 'Syracosphaera histrica', 'Syracosphaera lamina type']})])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       3 fig, axs = plt.subplots(2,1,figsize=(20, 8))
#       4 fig.suptitle('Top contributors per oceanographic region')
# ----> 5 p.top_size_groups_boxplot(traits, region="Northern Temperate Gyres", log=True, ax=axs[0])
#       6 p.top_size_groups_boxplot(traits, region="Southern Subantarctic", log=True, ax=axs[1])
#       7 fig.tight_layout()
#
# File ~/planktonSDM/plotting.py:67, in plot.top_size_groups_boxplot(self, traits, region, ax, log)
#      60         print(size_groups.items())
#      61 #        df = d[species] #subset based on
#      62
#      63
#      64
#      65         # d = None
#      66         # df.reset_index(inplace=True)
# ---> 67         df = pd.melt(d, id_vars=['lat', 'lon', 'depth', 'time', 'FID'], value_vars=species_abrv)
#      68         # df_sum = df.groupby('variable').sum().sort_values(by='value',ascending=False)
#      69         # df_sum.reset_index(inplace=True)
#      70         # top_spp = df_sum['variable'].head(5)
#      71         # df_top = df.query("variable.isin(@top_spp).values")
#      72         sns.boxplot(data = df, y="value", x="variable", ax=ax).set(title=region, xlabel='', ylabel='log biomass')
#
# File ~/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/reshape/melt.py:73, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      71         missing = Index(com.flatten(id_vars)).difference(cols)
#      72         if not missing.empty:
# ---> 73             raise KeyError(
#      74                 "The following 'id_vars' are not present "
#      75                 f"in the DataFrame: {list(missing)}"
#      76             )
#      77 else:
#      78     id_vars = []
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['FID', 'depth', 'lat', 'lon', 'time']"
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
traits = pd.read_csv("/home/phyto/CoccoML/data/traits.csv")

fig, axs = plt.subplots(2,1,figsize=(20, 8))
fig.suptitle('Top contributors per oceanographic region')
p.top_spp_boxplot(traits, region="Northern Temperate Gyres", log=True, ax=axs[0])
p.top_spp_boxplot(traits, region="Southern Subantarctic", log=True, ax=axs[1])
fig.tight_layout()
# Out:
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)

# %%
traits = pd.read_csv("/home/phyto/CoccoML/data/traits.csv")
region = "NPTG"

fig, axs = plt.subplots(2,4,figsize=(20, 8))
fig.suptitle('Top contributors per oceanographic region')
p.top_spp_boxplot(traits, region="Global", log=True, ax=axs[0,0])
p.top_spp_boxplot(traits, region="North Atlantic Polar", log=True, ax=axs[0,1])
p.top_spp_boxplot(traits, region="Northern Temperate Gyres", log=True, ax=axs[0,2])
p.top_spp_boxplot(traits, region="Tropical Gyres", log=True, ax=axs[0,3])
p.top_spp_boxplot(traits, region="Equatorial Upwelling", log=True, ax=axs[1,0])
p.top_spp_boxplot(traits, region="Indian Ocean Tropical", log=True, ax=axs[1,1])
p.top_spp_boxplot(traits, region="South Subtropical Convergence", log=True, ax=axs[1,2])
p.top_spp_boxplot(traits, region="Southern Subantarctic", log=True, ax=axs[1,3])
fig.tight_layout()
# Out:
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)
# /home/phyto/anaconda3/envs/my-geopandas-env-2/lib/python3.11/site-packages/pandas/core/internals/blocks.py:329: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)
# /home/phyto/planktonSDM/plotting.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=test, inplace=True)

# %%
#boxplots with diversity, total biomass, and cwm size as y, regions as x
