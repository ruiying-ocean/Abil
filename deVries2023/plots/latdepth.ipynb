# %%
import xarray as xr
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
import sys

#import custom functions:
sys.path.insert(0, '/home/phyto/planktonSDM/functions/')
from plotting import plot_latdepth


ds = xr.open_dataset("/home/phyto/ModelOutput/merged/biomass_menden.nc")



p = plot_latdepth(ds)

# %%
import cartopy.crs as ccrs


fig, axs = plt.subplots(2,3, figsize=(20, 8))
fig.suptitle('Distribution of size classes')
fig.tight_layout(h_pad=6)

p.make_plot("3-4 um", log=True, ax=axs[0,0], fig=fig)
p.make_plot("5 um", log=True, ax=axs[0,1], fig=fig)
p.make_plot("6-7 um", log=True, ax=axs[0,2], fig=fig)
p.make_plot("8-12 um", log=True, ax=axs[1,0], fig=fig)
p.make_plot("13-16 um", log=True, ax=axs[1,1], fig=fig)
p.make_plot("13-16 um", log=True, ax=axs[1,2], fig=fig)

plt.subplots_adjust(bottom=0.15, wspace=0.1)

# %%
import cartopy.crs as ccrs


fig, axs = plt.subplots(1, 3, figsize=(20, 4))
fig.suptitle('Distribution of size classes')

p.make_plot("total", log=True, ax=axs[0], fig=fig)
p.make_plot("cwm cell diameter", log=True, ax=axs[1], fig=fig)
p.make_plot("simpson", log=True, ax=axs[2], fig=fig)

# %%
p.make_plot("total", log=True)

# %%
p.make_plot("simpson")

# %%
p.make_plot("cwm cell diameter")

# %%
p.make_plot("Emiliania huxleyi", log=True)

# %%
p.make_plot("Coccolithus pelagicus", log=True)

# %%
p.make_plot("Calcidiscus leptoporus", log=True)

# %%
p.make_plot("Umbellosphaera tenuis", log=True)

# %%
p.make_plot("Umbellosphaera irregularis", log=True)

# %%
p.make_plot("Florisphaera profunda", log=False)

# %%
p.make_plot("Gephyrocapsa ericsonii", log=True)

# %%
p.make_plot("Gephyrocapsa oceanica", log=True)

# %%
p.make_plot("Gephyrocapsa muellerae", log=True)

# %%
p.make_plot("Algirosphaera robusta", log=True)

# %%
p.make_plot("Syracosphaera pulchra", log=True)

# %%
p.make_plot("Syracosphaera pulchra HOL", log=True)

# %%
p.make_plot("Coronosphaera mediterranea", log=True)

# %%
p.make_plot("Syracosphaera mediterranea HOL type", log=True)

# %%
p.make_plot("Discosphaera tubifera", log=True)

# %%
p.make_plot("Rhabdosphaera clavigera", log=True)

# %%
p.make_plot("Umbilicosphaera sibogae", log=True)

# %%
p.make_plot("Ophiaster hydroideus", log=True)

# %%
p.make_plot("Syracosphaera lamina type", log=True)
