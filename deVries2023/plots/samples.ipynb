# %%
import xarray as xr
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
import sys

#import custom functions:
sys.path.insert(0, '/home/phyto/planktonSDM/functions/')
from plotting import plot_xy


ds = xr.open_dataset("/home/phyto/ModelOutput/merged/biomass_menden.nc")



p = plot_xy(ds)

# %%
d = pd.read_csv("/home/phyto/CoccoML/data/abundances/sal2013.csv")
p.training_latlon( d=d, variable= "din")
